# %%
import matplotlib.pyplot as plt
import random
import math
import numpy as np
import pandas as pd

# Ensuring reproducibility
random.seed(42)
np.random.seed(42)

# %% [markdown]
# ## Congifuration and parameters

# %%
# Configuration
CONFIG = {
    "BASE_LEGITIMACY_List": [0.2, 0.4, 0.6, 0.8],
    "iterations": 200 ,
    "max_time_steps": 50,
    "initial_agent_vision_cases": ['High'],
    "shock_rate_cases": ['High', 'Low'],
    "cops_ratio_cases": ['High']
}

# Parameters
Quality_of_life_index = 50
Corruption_perceptions_index = 50
internet_disconnection = 0

# Constants
SHOCK_RATE = 5
COPS_RATIO = 20
REVOLUTION_THRESHOLD = 0.35

# Global variables
BASE_LEGITIMACY = ((Quality_of_life_index / 79 * 100) + (Corruption_perceptions_index / 90 * 100)) / 200
legitimacy = BASE_LEGITIMACY
delta_legitimacy = 0
world_status = 0
initial_agent_vision = 2
agent_vision = initial_agent_vision
government_utility = 1
reform_value = 0
protestors_ratio = 0.0
indirect_reform = 0
shock_is_happening = False
active_agents = 0
jailed_agents = 0
killed_agents = 0

# %% [markdown]
# ## Citizens Class

# %%
class Agent:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.risk_aversion = random.random()
        self.rage = random.random()
        self.status = "quiet"
        self.vision = initial_agent_vision
        self.jailed_time = 0
        self.neighbor_killed = 0
        self.neighbor_active = 0
        self.neighbor_jailed = 0

    def update_status(self, agents):
        global legitimacy, internet_disconnection, protestors_ratio, reform_value, shock_is_happening, indirect_reform
        self.neighbor_killed_1 = len([agent for agent in agents if agent.status == "killed" and
                                abs(agent.x - self.x) <= self.vision and abs(agent.y - self.y) <= self.vision])
        self.neighbor_active_1 = len([agent for agent in agents if agent.status == "active" and
                                abs(agent.x - self.x) <= self.vision and abs(agent.y - self.y) <= self.vision])
        self.neighbor_jailed_1 = len([agent for agent in agents if agent.status == "jailed" and
                                abs(agent.x - self.x) <= self.vision and abs(agent.y - self.y) <= self.vision])

        self.stimuli = (self.neighbor_killed_1 - self.neighbor_killed) * 0.08 + (self.neighbor_jailed_1 - self.neighbor_jailed) * 0.01 + (self.neighbor_active_1 - self.neighbor_active) * 0.003

        if random.random() * 100 < SHOCK_RATE:
            shock_is_happening = 1
        else:
            shock_is_happening = 0

        self.rage += self.stimuli + shock_is_happening * random.gauss(0.02, 0.03) - reform_value
        self.risk_aversion += (self.neighbor_killed_1 - self.neighbor_killed) * 0.1 + (self.neighbor_jailed_1 - self.neighbor_jailed) * 0.005 - reform_value * (1- 0.4 *indirect_reform)

        self.neighbor_killed = self.neighbor_killed_1
        self.neighbor_active = self.neighbor_active_1
        self.neighbor_jailed = self.neighbor_jailed_1

        self.condition = self.rage - self.risk_aversion - legitimacy
        if self.status == "jailed":
            self.jailed_time -= 1
            if self.jailed_time <= 0:
                if self.condition > 0:
                    self.status = "active"
                else:
                    self.status = "quiet"
        else:
            if self.status == "quiet" or self.status == "active":
                if self.condition > 0.0:
                    self.status = "active"
                else:
                    self.status = "quiet"

        if internet_disconnection == 1:
            if REVOLUTION_THRESHOLD - protestors_ratio <= 0.1:
                self.vision = 2
            else:
                self.vision = initial_agent_vision
        else:
            self.vision = initial_agent_vision

# %% [markdown]
# ## Cops Class

# %%
class Cop:
    def __init__(self, x, y):
        global initial_agent_vision, legitimacy, protestors_ratio
        self.x = x
        self.y = y
        self.vision = round(initial_agent_vision * 1.5)
        self.violence_level = random.random() * ((1 - legitimacy) * (protestors_ratio + 0.001))

    def suppress(self, agents):
        global legitimacy, protestors_ratio
        self.nearby_active_agents = [agent for agent in agents if agent.status == "active" and
                                abs(agent.x - self.x) <= self.vision and abs(agent.y - self.y) <= self.vision]

        self.violence_level = random.random() * ((1 - legitimacy) * (protestors_ratio + 0.001))

        if self.nearby_active_agents:
            target = random.choice(self.nearby_active_agents)
            if self.violence_level > 0.12:
                target.status = "killed"
            else:
                target.status = "jailed"
                target.jailed_time = random.randint(0, int((protestors_ratio + 0.05) * 30))

# %% [markdown]
# ## Cops Strategies

# %%
def cops_suppress(cops, agents):
    for cop in cops:
        cop.suppress(agents)

def cops_reform(cops, agents):
    global government_utility, reform_value
    reform_value = protestors_ratio * 0.2  # Calculate reform value based on some metric

def cops_contingent_suppress_low(cops, agents):
    global protestors_ratio
    if protestors_ratio < 0.30:
        cops_suppress(cops, agents)
    else:
        cops_reform(cops, agents)

def cops_contingent_suppress_high(cops, agents):
    global protestors_ratio
    if protestors_ratio >= 0.30:
        cops_suppress(cops, agents)
    else:
        cops_reform(cops, agents)

def cops_mixed(cops, agents):
    cops_suppress(cops, agents)
    cops_reform(cops, agents)

def cops_suppress_ind_reform(cops, agents):
    global indirect_reform, reform_value, protestors_ratio
    cops_suppress(cops, agents)
    if protestors_ratio < 0.15:
        indirect_reform = 1
        reform_value = protestors_ratio * 0.2
    else:
        indirect_reform = 0

# %% [markdown]
# ## World Setup

# %%
def setup():
    global COPS_RATIO
    agents = []
    cops = []

    # Create agents
    total_patches = 400  # Assuming 20x20 grid
    agent_patches = 0.8 * total_patches
    cop_patches = COPS_RATIO / 100 * total_patches

    while len(agents) < agent_patches:
        x = random.randint(1, 20)
        y = random.randint(1, 20)
        if (x, y) not in [(agent.x, agent.y) for agent in agents]:
            agents.append(Agent(x, y))

    # Create cops
    while len(cops) < cop_patches:
        x = random.randint(1, 20)
        y = random.randint(1, 20)
        if (x, y) not in [(agent.x, agent.y) for agent in agents] and \
                (x, y) not in [(cop.x, cop.y) for cop in cops]:
            cops.append(Cop(x, y))

    return agents, cops

# %% [markdown]
# ## Updating the Stats

# %%
def update_stats(agents):
    global active_agents, jailed_agents, killed_agents
    active_agents_so_far = [agent for agent in agents if agent.status == "active"]
    jailed_agents_so_far = [agent for agent in agents if agent.status == "jailed"]
    killed_agents_so_far = [agent for agent in agents if agent.status == "killed"]

    active_agents = len(active_agents_so_far) - active_agents    # Number of active agents in this iteration
    jailed_agents = len(jailed_agents_so_far) - jailed_agents   # Number of jailed agents in this iteration
    killed_agents = len(killed_agents_so_far) - killed_agents   # Number of killed agents in this iteration

# %% [markdown]
# ## Updating Global Variables

# %%
def update_globals(agents):
    global legitimacy, world_status, protestors_ratio, delta_legitimacy, reform_value, government_utility, jailed_agents, active_agents, killed_agents, REVOLUTION_THRESHOLD
    update_stats(agents)

    legitimacy_prev = legitimacy
    legitimacy = (legitimacy / (math.exp(0.05 * killed_agents + 0.02 * jailed_agents))) + reform_value * random.random()   # updating legitimacy based on number of killed and jailed agents in this iteration, the credit that it gets from reform and a random factor
    if legitimacy > 1:
        legitimacy = 1
    elif legitimacy < 0:
        legitimacy = 0

    delta_legitimacy = legitimacy_prev - legitimacy

    total_agents = sum(1 for agent in agents if agent.status == "active" or agent.status == "jailed" or agent.status == "quiet")
    active_agents_2 = sum(1 for agent in agents if agent.status == "active")
    jailed_agents_2 = sum(1 for agent in agents if agent.status == "jailed")
    active_and_jailed = active_agents_2 + jailed_agents_2
    protestors_ratio = active_and_jailed / total_agents

    world_status = 1 if protestors_ratio >= REVOLUTION_THRESHOLD else 0

    if world_status == 0:
            government_utility -= protestors_ratio * 0.1 + random.random() * delta_legitimacy + reform_value
            if government_utility > 1:
                government_utility = 1
    else:
            government_utility = 0

# %% [markdown]
# ## Updating Citizens' Statuses

# %%
def update_agents_status(agents):
    for agent in agents:
        agent.update_status(agents)

# %% [markdown]
# ## Running the Simulation

# %%
def run_simulation(base_legitimacy, iterations, max_time_steps, vision, shock_rate, cops_ratio, strategy_type):
    global legitimacy, initial_agent_vision, SHOCK_RATE, COPS_RATIO
    global government_utility, reform_value, protestors_ratio, indirect_reform, active_agents, jailed_agents, killed_agents, world_status

    results = []

    for iter_num in range(iterations):
        # Initialize global variables
        legitimacy = base_legitimacy
        initial_agent_vision = 4 if vision == 'Low' else 20
        SHOCK_RATE = 10 if shock_rate == 'Low' else 90
        COPS_RATIO = 5 if cops_ratio == 'Low' else 20
        government_utility = 1
        reform_value = 0
        protestors_ratio = 0.0
        indirect_reform = 0
        active_agents = 0
        jailed_agents = 0
        killed_agents = 0
        world_status = 0

        agents, cops = setup()
        time_step = 0
        gov_util_record = []
        protestors_ratio_record = []

        print(f"Iteration {iter_num+1}/{iterations}, Strategy: {strategy_type}, Legitimacy: {base_legitimacy}, Vision: {vision}, Shock Rate: {shock_rate}, Cops Ratio: {cops_ratio}")

        while time_step < max_time_steps and world_status == 0 and government_utility > 0:
            update_globals(agents)
            strategy(cops, agents, strategy_type)
            update_agents_status(agents)
            gov_util_record.append(government_utility)
            protestors_ratio_record.append(protestors_ratio)
            time_step += 1

            print(f"  Time Step: {time_step}, Government Utility: {government_utility}, Protestors Ratio: {protestors_ratio}, World Status: {world_status}")

        gov_lifetime_util = 0
        for i in range(len(gov_util_record)):
            gov_lifetime_util += gov_util_record[i] * (0.95 ** i)
        results.append((gov_lifetime_util, time_step))

    avg_gov_lifetime_util = np.mean([res[0] for res in results])
    avg_lifetime = np.mean([res[1] for res in results])

    #print(f"Simulation results for strategy: {strategy_type}, legitimacy: {base_legitimacy}, vision: {vision}, shock_rate: {shock_rate}, cops_ratio: {cops_ratio}")
    #print(f"Avg Gov Lifetime Utility: {avg_gov_lifetime_util}, Avg Lifetime: {avg_lifetime}")

    return avg_gov_lifetime_util, avg_lifetime


## Selecting the Government Strategy
def strategy(cops, agents, strategy_type):
    if strategy_type == 'Consistent Suppression':
        cops_suppress(cops, agents)
    elif strategy_type == 'Consistent Reform':
        cops_reform(cops, agents)
    elif strategy_type == 'Threshold-Based Mixed Strategy (Suppression First)':
        cops_contingent_suppress_low(cops, agents)
    elif strategy_type == 'Threshold-Based Mixed Strategy (Reform First)':
        cops_contingent_suppress_high(cops, agents)
    elif strategy_type == 'Suppression and Indirect Reform Strategy':
        cops_suppress_ind_reform(cops, agents)

# %% [markdown]
# ## Presenting the Results in Table Format

# %%
def display_results(results, results_df):
    """
    Displays the results in tabular format.
    """
    print("\nSummary of Average Government Lifetime Utility and Stability by Strategy and Legitimacy Level\n")
    summary_table = results_df.pivot_table(index='Base Legitimacy', columns='Strategy', values=['Avg Gov Lifetime Utility', 'Avg Duration of Stability'])
    print(summary_table)

    print("\nComparison of Strategies Across Different Shock Rates\n")
    shock_table = results_df.pivot_table(index='Shock Rate', columns='Strategy', values=['Avg Gov Lifetime Utility', 'Avg Duration of Stability'])
    print(shock_table)

    print("\nDetailed Results for Each Scenario\n")
    detailed_table = results_df.pivot_table(index=['Vision', 'Shock Rate', 'Cops Ratio'], columns='Strategy', values=['Avg Gov Lifetime Utility', 'Avg Duration of Stability'])
    print(detailed_table)

# %% [markdown]
# ## Presenting the Results in Plot Format

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_results(results):
    """
    Plots the results of the simulation.
    """
    num_scenarios = len(results)
    cols = 2
    rows = (num_scenarios + cols - 1) // cols  # Calculate number of rows needed

    fig, axs = plt.subplots(rows, cols, figsize=(15, 5 * rows))
    axs = axs.flatten()

    for i, (scenario, data) in enumerate(results.items()):
        print(f"Plotting scenario: {scenario} with {len(data)} data points.")
        if data:
            try:
                strategies, base_legitimacies, avg_gov_utils, avg_lifetimes = zip(*data)

                # Aggregate data for simple scenarios
                unique_legitimacies = sorted(set(base_legitimacies))
                aggregated_data = {strategy: {leg: [] for leg in unique_legitimacies} for strategy in set(strategies)}

                for strategy, leg, agu, al in data:
                    aggregated_data[strategy][leg].append(agu)

                for strategy in aggregated_data:
                    leg_values = []
                    agu_means = []
                    agu_stds = []
                    for leg in unique_legitimacies:
                        leg_values.append(leg)
                        agu_means.append(np.mean(aggregated_data[strategy][leg]))
                        agu_stds.append(np.std(aggregated_data[strategy][leg]))

                    axs[i].errorbar(leg_values, agu_means, yerr=agu_stds, label=f"{strategy} - Avg Gov Util", capsize=3)

                axs[i].set_title(scenario)
                axs[i].set_xlabel("BASE_LEGITIMACY")
                axs[i].set_ylabel("Values")
                axs[i].legend()
            except ValueError as e:
                #print(f"Error unpacking data for scenario '{scenario}': {e}")
                axs[i].text(0.5, 0.5, 'No data', horizontalalignment='center', verticalalignment='center')
        else:
            axs[i].set_title(scenario)
            axs[i].text(0.5, 0.5, 'No data', horizontalalignment='center', verticalalignment='center')

    # Hide any unused subplots
    for j in range(i + 1, len(axs)):
        fig.delaxes(axs[j])

    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_results_lifetime(results):
    """
    Plots the results of the simulation.
    """
    num_scenarios = len(results)
    cols = 2
    rows = (num_scenarios + cols - 1) // cols  # Calculate number of rows needed

    fig, axs = plt.subplots(rows, cols, figsize=(15, 5 * rows))
    axs = axs.flatten()

    for i, (scenario, data) in enumerate(results.items()):
        print(f"Plotting scenario: {scenario} with {len(data)} data points.")
        if data:
            try:
                strategies, base_legitimacies, avg_gov_utils, avg_lifetimes = zip(*data)

                # Aggregate data for simple scenarios
                unique_legitimacies = sorted(set(base_legitimacies))
                aggregated_data = {strategy: {leg: [] for leg in unique_legitimacies} for strategy in set(strategies)}

                for strategy, leg, agu, al in data:
                    aggregated_data[strategy][leg].append(al)  # Append avg_lifetime instead of avg_gov_util

                for strategy in aggregated_data:
                    leg_values = []
                    al_means = []
                    al_stds = []
                    for leg in unique_legitimacies:
                        leg_values.append(leg)
                        al_means.append(np.mean(aggregated_data[strategy][leg]))
                        al_stds.append(np.std(aggregated_data[strategy][leg]))

                    axs[i].errorbar(leg_values, al_means, yerr=al_stds, label=f"{strategy} - Avg Lifetime", capsize=3)

                axs[i].set_title(scenario)
                axs[i].set_xlabel("BASE_LEGITIMACY")
                axs[i].set_ylabel("Government Avg Lifetime")
                axs[i].legend()
            except ValueError as e:
                #print(f"Error unpacking data for scenario '{scenario}': {e}")
                axs[i].text(0.5, 0.5, 'No data', horizontalalignment='center', verticalalignment='center')
        else:
            axs[i].set_title(scenario)
            axs[i].text(0.5, 0.5, 'No data', horizontalalignment='center', verticalalignment='center')

    # Hide any unused subplots
    for j in range(i + 1, len(axs)):
        fig.delaxes(axs[j])

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Drawing the world

# %%
def draw(agents, cops):
    plt.clf()

    # Draw agents
    for agent in agents:
        if agent.status == "active":
            color = "red"
        elif agent.status == "quiet":
            color = "yellow"
        elif agent.status == "jailed":
            color = "grey"
        elif agent.status == "killed":
            color = "black"
        plt.scatter(agent.x, agent.y, color=color, marker="x" if agent.status == "killed" else "o")

    # Draw cops
    for cop in cops:
        plt.scatter(cop.x, cop.y, color="blue", marker="^")

    plt.xlim(0, 21)
    plt.ylim(0, 21)
    plt.pause(0.001)

# %% [markdown]
# ## Defining the Main Loop

# %%
def main():
    results = {}
    strategies = [
        'Consistent Suppression',
        'Consistent Reform',
        'Suppression and Indirect Reform Strategy'
    ]

    all_results = []

    for strategy_type in strategies:
        for base_legitimacy in CONFIG["BASE_LEGITIMACY_List"]:
            for vision in CONFIG["initial_agent_vision_cases"]:
                for shock_rate in CONFIG["shock_rate_cases"]:
                    for cops_ratio in CONFIG["cops_ratio_cases"]:
                        avg_gov_lifetime_util, avg_lifetime = run_simulation(
                            base_legitimacy,
                            CONFIG["iterations"],
                            CONFIG["max_time_steps"],
                            vision,
                            shock_rate,
                            cops_ratio,
                            strategy_type
                        )
                        complex_scenario = f"{vision} Vision, {shock_rate} Shock Rate, {cops_ratio} Cops Ratio"
                        simple_scenarios = {
                            "High Legitimacy": base_legitimacy > 0.5,
                            "Low Legitimacy": base_legitimacy <= 0.5,
                            "High Shock Rate": shock_rate == 'High',
                            "Low Shock Rate": shock_rate == 'Low',
                            "High Vision": vision == 'High',
                            "Low Vision": vision == 'Low',
                            "High Cops Ratio": cops_ratio == 'High',
                            "Low Cops Ratio": cops_ratio == 'Low'
                        }

                        for scenario, condition in simple_scenarios.items():
                            if condition:
                                if scenario not in results:
                                    results[scenario] = []
                                results[scenario].append((strategy_type, base_legitimacy, avg_gov_lifetime_util, avg_lifetime))

                        if complex_scenario not in results:
                            results[complex_scenario] = []
                        results[complex_scenario].append((strategy_type, base_legitimacy, avg_gov_lifetime_util, avg_lifetime))
                        all_results.append((vision, shock_rate, cops_ratio, strategy_type, base_legitimacy, avg_gov_lifetime_util, avg_lifetime))

    results_df = pd.DataFrame(all_results, columns=['Vision', 'Shock Rate', 'Cops Ratio', 'Strategy', 'Base Legitimacy', 'Avg Gov Lifetime Utility', 'Avg Duration of Stability'])
    display_results(results, results_df)
    plot_results(results)
    plot_results_lifetime(results)

# %%
if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
#   Time Step: 15, Government Utility: 0.043608857477542895, Protestors Ratio: 0.027450980392156862, World Status: 0
#   Time Step: 16, Government Utility: 0.03595701344819084, Protestors Ratio: 0.023529411764705882, World Status: 0
#   Time Step: 17, Government Utility: 0.026259373621952624, Protestors Ratio: 0.00784313725490196, World Status: 0
#   Time Step: 18, Government Utility: 0.024645823235548238, Protestors Ratio: 0.00392156862745098, World Status: 0
#   Time Step: 19, Government Utility: 0.022877165162250693, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 20, Government Utility: 0.022948789610753972, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 21, Government Utility: 0.02274593423549976, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 22, Government Utility: 0.02235611971036812, Protestors Ratio: 0.00392156862745098, World Status: 0
#   Time Step: 23, Government Utility: 0.02146468453789401, Protestors Ratio: 0.00392156862745098, World Status: 0
#   Time Step: 24, Government Utility: 0.020394927948541412, Protestors Ratio: 0.00392156862745098, World Status: 0
#   Time Step: 25, Government Utility: 0.018822352918883907, Protestors Ratio: 0.00784313725490196, World Status: 0
#   Time Step: 26, Government Utility: 0.017424186549455965, Protestors Ratio: 0.011764705882352941, World Status: 0
#   Time Step: 27, Government Utility: 0.011531766867028937, Protestors Ratio: 0.023529411764705882, World Status: 0
#   Time Step: 28, Government Utility: 0.005884870507536044, Protestors Ratio: 0.023529411764705882, World Status: 0
#   Time Step: 29, Government Utility: -0.0027064759724931943, Protestors Ratio: 0.023529411764705882, World Status: 0
# Iteration 185/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.995, Protestors Ratio: 0.05, World Status: 0
#   Time Step: 3, Government Utility: 0.9621985346862387, Protestors Ratio: 0.059375, World Status: 0
#   Time Step: 4, Government Utility: 0.9278286097663263, Protestors Ratio: 0.0875, World Status: 0
#   Time Step: 5, Government Utility: 0.8689713159195458, Protestors Ratio: 0.175, World Status: 0
#   Time Step: 6, Government Utility: 0.5055568283478308, Protestors Ratio: 0.31875, World Status: 0
#   Time Step: 7, Government Utility: 0.37037005700756553, Protestors Ratio: 0.23972602739726026, World Status: 0
#   Time Step: 8, Government Utility: 0.32804333950158227, Protestors Ratio: 0.22377622377622378, World Status: 0
#   Time Step: 9, Government Utility: 0.2674757580558924, Protestors Ratio: 0.20640569395017794, World Status: 0
#   Time Step: 10, Government Utility: 0.2317540396674408, Protestors Ratio: 0.17985611510791366, World Status: 0
#   Time Step: 11, Government Utility: 0.2004009972861134, Protestors Ratio: 0.14233576642335766, World Status: 0
#   Time Step: 12, Government Utility: 0.15844061692239175, Protestors Ratio: 0.12087912087912088, World Status: 0
#   Time Step: 13, Government Utility: 0.12312684999382757, Protestors Ratio: 0.10989010989010989, World Status: 0
#   Time Step: 14, Government Utility: 0.09348963215309034, Protestors Ratio: 0.10256410256410256, World Status: 0
#   Time Step: 15, Government Utility: 0.06347065613921524, Protestors Ratio: 0.08791208791208792, World Status: 0
#   Time Step: 16, Government Utility: 0.04033398569916187, Protestors Ratio: 0.0695970695970696, World Status: 0
#   Time Step: 17, Government Utility: 0.02012819377676008, Protestors Ratio: 0.05860805860805861, World Status: 0
#   Time Step: 18, Government Utility: 0.0009338259226697905, Protestors Ratio: 0.05860805860805861, World Status: 0
#   Time Step: 19, Government Utility: -0.015850225759409312, Protestors Ratio: 0.054945054945054944, World Status: 0
# Iteration 186/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.99625, Protestors Ratio: 0.0375, World Status: 0
#   Time Step: 3, Government Utility: 0.9821053917301154, Protestors Ratio: 0.046875, World Status: 0
#   Time Step: 4, Government Utility: 0.9674668904232977, Protestors Ratio: 0.08125, World Status: 0
#   Time Step: 5, Government Utility: 0.922628241139241, Protestors Ratio: 0.103125, World Status: 0
#   Time Step: 6, Government Utility: 0.8223673118998857, Protestors Ratio: 0.190625, World Status: 0
#   Time Step: 7, Government Utility: 0, Protestors Ratio: 0.496875, World Status: 1
# Iteration 187/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.996875, Protestors Ratio: 0.03125, World Status: 0
#   Time Step: 3, Government Utility: 0.9831629277408582, Protestors Ratio: 0.040625, World Status: 0
#   Time Step: 4, Government Utility: 0.9785213417124364, Protestors Ratio: 0.059375, World Status: 0
#   Time Step: 5, Government Utility: 0.9082686400094089, Protestors Ratio: 0.075, World Status: 0
#   Time Step: 6, Government Utility: 0.8744575139699022, Protestors Ratio: 0.190625, World Status: 0
#   Time Step: 7, Government Utility: 0, Protestors Ratio: 0.365625, World Status: 1
# Iteration 188/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9978125, Protestors Ratio: 0.021875, World Status: 0
#   Time Step: 3, Government Utility: 0.9884223671028929, Protestors Ratio: 0.040625, World Status: 0
#   Time Step: 4, Government Utility: 0.9824556552741035, Protestors Ratio: 0.075, World Status: 0
#   Time Step: 5, Government Utility: 0.8890196582145444, Protestors Ratio: 0.09375, World Status: 0
#   Time Step: 6, Government Utility: 0.8333417880211139, Protestors Ratio: 0.278125, World Status: 0
#   Time Step: 7, Government Utility: 0, Protestors Ratio: 0.50625, World Status: 1
# Iteration 189/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.998125, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 3, Government Utility: 0.9750025708427718, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 4, Government Utility: 0.9882264616054731, Protestors Ratio: 0.0625, World Status: 0
#   Time Step: 5, Government Utility: 0.879952803001954, Protestors Ratio: 0.06875, World Status: 0
#   Time Step: 6, Government Utility: 0.8491959328822469, Protestors Ratio: 0.2375, World Status: 0
#   Time Step: 7, Government Utility: 0, Protestors Ratio: 0.409375, World Status: 1
# Iteration 190/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.998125, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 3, Government Utility: 0.9637962469625103, Protestors Ratio: 0.034375, World Status: 0
#   Time Step: 4, Government Utility: 0.9454844168353925, Protestors Ratio: 0.053125, World Status: 0
#   Time Step: 5, Government Utility: 0.861748213282002, Protestors Ratio: 0.078125, World Status: 0
#   Time Step: 6, Government Utility: 0.8089906901751553, Protestors Ratio: 0.121875, World Status: 0
#   Time Step: 7, Government Utility: 0.5996707039517271, Protestors Ratio: 0.225, World Status: 0
#   Time Step: 8, Government Utility: 0, Protestors Ratio: 0.49683544303797467, World Status: 1
# Iteration 191/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.996875, Protestors Ratio: 0.03125, World Status: 0
#   Time Step: 3, Government Utility: 0.915889056780695, Protestors Ratio: 0.0625, World Status: 0
#   Time Step: 4, Government Utility: 0.8861262052908025, Protestors Ratio: 0.121875, World Status: 0
#   Time Step: 5, Government Utility: 0.8266890238247421, Protestors Ratio: 0.178125, World Status: 0
#   Time Step: 6, Government Utility: 0, Protestors Ratio: 0.5625, World Status: 1
# Iteration 192/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.998125, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 3, Government Utility: 0.9644379768336093, Protestors Ratio: 0.0375, World Status: 0
#   Time Step: 4, Government Utility: 0.9432026565944417, Protestors Ratio: 0.046875, World Status: 0
#   Time Step: 5, Government Utility: 0.9166878272599663, Protestors Ratio: 0.065625, World Status: 0
#   Time Step: 6, Government Utility: 0.879019616722946, Protestors Ratio: 0.09375, World Status: 0
#   Time Step: 7, Government Utility: 0.7007409187748876, Protestors Ratio: 0.23125, World Status: 0
#   Time Step: 8, Government Utility: 0, Protestors Ratio: 0.5015873015873016, World Status: 1
# Iteration 193/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9978125, Protestors Ratio: 0.021875, World Status: 0
#   Time Step: 3, Government Utility: 0.9716596380067933, Protestors Ratio: 0.028125, World Status: 0
#   Time Step: 4, Government Utility: 0.9518612323142737, Protestors Ratio: 0.05625, World Status: 0
#   Time Step: 5, Government Utility: 0.879719861844373, Protestors Ratio: 0.075, World Status: 0
#   Time Step: 6, Government Utility: 0.7880441287995024, Protestors Ratio: 0.175, World Status: 0
#   Time Step: 7, Government Utility: 0, Protestors Ratio: 0.421875, World Status: 1
# Iteration 194/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9965625, Protestors Ratio: 0.034375, World Status: 0
#   Time Step: 3, Government Utility: 0.9475520563757361, Protestors Ratio: 0.053125, World Status: 0
#   Time Step: 4, Government Utility: 0.9144892678414789, Protestors Ratio: 0.096875, World Status: 0
#   Time Step: 5, Government Utility: 0.7400151755700712, Protestors Ratio: 0.14375, World Status: 0
#   Time Step: 6, Government Utility: 0, Protestors Ratio: 0.38125, World Status: 1
# Iteration 195/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.999375, Protestors Ratio: 0.00625, World Status: 0
#   Time Step: 3, Government Utility: 0.9966980881813026, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 4, Government Utility: 0.9915696363059218, Protestors Ratio: 0.028125, World Status: 0
#   Time Step: 5, Government Utility: 0.928083416140096, Protestors Ratio: 0.0375, World Status: 0
#   Time Step: 6, Government Utility: 0.9349194711958148, Protestors Ratio: 0.0875, World Status: 0
#   Time Step: 7, Government Utility: 0.8058501101764183, Protestors Ratio: 0.109375, World Status: 0
#   Time Step: 8, Government Utility: 0.7351245152167802, Protestors Ratio: 0.30625, World Status: 0
#   Time Step: 9, Government Utility: 0.6195499133032702, Protestors Ratio: 0.24414715719063546, World Status: 0
#   Time Step: 10, Government Utility: 0, Protestors Ratio: 0.4387755102040816, World Status: 1
# Iteration 196/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.995625, Protestors Ratio: 0.04375, World Status: 0
#   Time Step: 3, Government Utility: 0.947184526562888, Protestors Ratio: 0.053125, World Status: 0
#   Time Step: 4, Government Utility: 0.9283322479258577, Protestors Ratio: 0.11875, World Status: 0
#   Time Step: 5, Government Utility: 0.7825786025867746, Protestors Ratio: 0.190625, World Status: 0
#   Time Step: 6, Government Utility: 0, Protestors Ratio: 0.59375, World Status: 1
# Iteration 197/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.998125, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 3, Government Utility: 0.9712976031676389, Protestors Ratio: 0.034375, World Status: 0
#   Time Step: 4, Government Utility: 0.9764939280186584, Protestors Ratio: 0.046875, World Status: 0
#   Time Step: 5, Government Utility: 0.9395966539260803, Protestors Ratio: 0.046875, World Status: 0
#   Time Step: 6, Government Utility: 0.9615151034318796, Protestors Ratio: 0.06875, World Status: 0
#   Time Step: 7, Government Utility: 0.8805418969374392, Protestors Ratio: 0.065625, World Status: 0
#   Time Step: 8, Government Utility: 0.8532475516648385, Protestors Ratio: 0.153125, World Status: 0
#   Time Step: 9, Government Utility: 0.6076316620469981, Protestors Ratio: 0.215625, World Status: 0
#   Time Step: 10, Government Utility: 0, Protestors Ratio: 0.6571428571428571, World Status: 1
# Iteration 198/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.99625, Protestors Ratio: 0.0375, World Status: 0
#   Time Step: 3, Government Utility: 0.9322284543692363, Protestors Ratio: 0.046875, World Status: 0
#   Time Step: 4, Government Utility: 0.9271885454357913, Protestors Ratio: 0.09375, World Status: 0
#   Time Step: 5, Government Utility: 0.847938324065944, Protestors Ratio: 0.10625, World Status: 0
#   Time Step: 6, Government Utility: 0.7281441643556434, Protestors Ratio: 0.253125, World Status: 0
#   Time Step: 7, Government Utility: 0, Protestors Ratio: 0.5691823899371069, World Status: 1
# Iteration 199/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.998125, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 3, Government Utility: 0.9812408201629242, Protestors Ratio: 0.0375, World Status: 0
#   Time Step: 4, Government Utility: 0.9653932254903137, Protestors Ratio: 0.05625, World Status: 0
#   Time Step: 5, Government Utility: 0.9256901648744617, Protestors Ratio: 0.075, World Status: 0
#   Time Step: 6, Government Utility: 0.8912119069623944, Protestors Ratio: 0.15, World Status: 0
#   Time Step: 7, Government Utility: 0.7451115420362644, Protestors Ratio: 0.30625, World Status: 0
#   Time Step: 8, Government Utility: 0.4788817679031356, Protestors Ratio: 0.25252525252525254, World Status: 0
#   Time Step: 9, Government Utility: 0, Protestors Ratio: 0.40955631399317405, World Status: 1
# Iteration 200/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: High, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9971875, Protestors Ratio: 0.028125, World Status: 0
#   Time Step: 3, Government Utility: 0.9556819623807328, Protestors Ratio: 0.0625, World Status: 0
#   Time Step: 4, Government Utility: 0.9510050157702065, Protestors Ratio: 0.128125, World Status: 0
#   Time Step: 5, Government Utility: 0.7091428424091022, Protestors Ratio: 0.15, World Status: 0
#   Time Step: 6, Government Utility: 0, Protestors Ratio: 0.5125, World Status: 1
# Iteration 1/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.99875, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 3, Government Utility: 0.9959889007707449, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 4, Government Utility: 0.9934118345570757, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 5, Government Utility: 0.9897040332523178, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 6, Government Utility: 0.986481506722792, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 7, Government Utility: 0.9837107343936383, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 8, Government Utility: 0.9801132135629215, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 9, Government Utility: 0.9763876325217674, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 10, Government Utility: 0.9743742900093246, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 11, Government Utility: 0.9712423252398834, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 12, Government Utility: 0.9682406895820436, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 13, Government Utility: 0.9656690790987235, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 14, Government Utility: 0.9607934987367607, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 15, Government Utility: 0.9530891559166359, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 16, Government Utility: 0.9453754837709483, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 17, Government Utility: 0.9120290431118728, Protestors Ratio: 0.025, World Status: 0
#   Time Step: 18, Government Utility: 0.9040948913624123, Protestors Ratio: 0.0375, World Status: 0
#   Time Step: 19, Government Utility: 0.8798373358877212, Protestors Ratio: 0.0375, World Status: 0
#   Time Step: 20, Government Utility: 0.8799133483029768, Protestors Ratio: 0.04375, World Status: 0
#   Time Step: 21, Government Utility: 0.8209910554453232, Protestors Ratio: 0.040625, World Status: 0
#   Time Step: 22, Government Utility: 0.8403186662396622, Protestors Ratio: 0.065625, World Status: 0
#   Time Step: 23, Government Utility: 0.731114132087947, Protestors Ratio: 0.065625, World Status: 0
#   Time Step: 24, Government Utility: 0.7078923274561207, Protestors Ratio: 0.14375, World Status: 0
#   Time Step: 25, Government Utility: 0.5863498590531979, Protestors Ratio: 0.196875, World Status: 0
#   Time Step: 26, Government Utility: 0.5196738759901455, Protestors Ratio: 0.266025641025641, World Status: 0
#   Time Step: 27, Government Utility: 0.3919535919767596, Protestors Ratio: 0.19795221843003413, World Status: 0
#   Time Step: 28, Government Utility: 0.34358894269529927, Protestors Ratio: 0.20819112627986347, World Status: 0
#   Time Step: 29, Government Utility: 0.2961285471493982, Protestors Ratio: 0.14788732394366197, World Status: 0
#   Time Step: 30, Government Utility: 0.261264864823836, Protestors Ratio: 0.13732394366197184, World Status: 0
#   Time Step: 31, Government Utility: 0.21714233408796185, Protestors Ratio: 0.11267605633802817, World Status: 0
#   Time Step: 32, Government Utility: 0.19057504184460908, Protestors Ratio: 0.09154929577464789, World Status: 0
#   Time Step: 33, Government Utility: 0.16230293706058094, Protestors Ratio: 0.07746478873239436, World Status: 0
#   Time Step: 34, Government Utility: 0.14177536045439307, Protestors Ratio: 0.0528169014084507, World Status: 0
#   Time Step: 35, Government Utility: 0.1233077610982273, Protestors Ratio: 0.014084507042253521, World Status: 0
#   Time Step: 36, Government Utility: 0.12182907883022884, Protestors Ratio: 0.014084507042253521, World Status: 0
#   Time Step: 37, Government Utility: 0.1073222551942074, Protestors Ratio: 0.014084507042253521, World Status: 0
#   Time Step: 38, Government Utility: 0.10406054435961369, Protestors Ratio: 0.017605633802816902, World Status: 0
#   Time Step: 39, Government Utility: 0.09822771276578326, Protestors Ratio: 0.017605633802816902, World Status: 0
#   Time Step: 40, Government Utility: 0.09379723388034353, Protestors Ratio: 0.017605633802816902, World Status: 0
#   Time Step: 41, Government Utility: 0.08763199742611397, Protestors Ratio: 0.02112676056338028, World Status: 0
#   Time Step: 42, Government Utility: 0.0829889979728191, Protestors Ratio: 0.02112676056338028, World Status: 0
#   Time Step: 43, Government Utility: 0.07628638425792508, Protestors Ratio: 0.02464788732394366, World Status: 0
#   Time Step: 44, Government Utility: 0.07133800315820105, Protestors Ratio: 0.028169014084507043, World Status: 0
#   Time Step: 45, Government Utility: 0.06010581695217647, Protestors Ratio: 0.03169014084507042, World Status: 0
#   Time Step: 46, Government Utility: 0.05473168691512693, Protestors Ratio: 0.03169014084507042, World Status: 0
#   Time Step: 47, Government Utility: 0.04522668836367527, Protestors Ratio: 0.03169014084507042, World Status: 0
#   Time Step: 48, Government Utility: 0.03710393829214109, Protestors Ratio: 0.02464788732394366, World Status: 0
#   Time Step: 49, Government Utility: 0.024296594583061555, Protestors Ratio: 0.028169014084507043, World Status: 0
#   Time Step: 50, Government Utility: 0.01635501079251317, Protestors Ratio: 0.028169014084507043, World Status: 0
# Iteration 2/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9975, Protestors Ratio: 0.025, World Status: 0
#   Time Step: 3, Government Utility: 0.9822522770061638, Protestors Ratio: 0.025, World Status: 0
#   Time Step: 4, Government Utility: 0.9910070143034968, Protestors Ratio: 0.04375, World Status: 0
#   Time Step: 5, Government Utility: 0.9596310571558189, Protestors Ratio: 0.040625, World Status: 0
#   Time Step: 6, Government Utility: 0.992448323320563, Protestors Ratio: 0.08125, World Status: 0
#   Time Step: 7, Government Utility: 0.9400595679706756, Protestors Ratio: 0.065625, World Status: 0
#   Time Step: 8, Government Utility: 1, Protestors Ratio: 0.2, World Status: 0
#   Time Step: 9, Government Utility: 0.7956301818598741, Protestors Ratio: 0.25625, World Status: 0
#   Time Step: 10, Government Utility: 0.674556851646572, Protestors Ratio: 0.264026402640264, World Status: 0
#   Time Step: 11, Government Utility: 0.6332231234051722, Protestors Ratio: 0.22866894197952217, World Status: 0
#   Time Step: 12, Government Utility: 0.5875338609427282, Protestors Ratio: 0.1951219512195122, World Status: 0
#   Time Step: 13, Government Utility: 0.5516395349731977, Protestors Ratio: 0.1824561403508772, World Status: 0
#   Time Step: 14, Government Utility: 0.5247040130152945, Protestors Ratio: 0.16140350877192983, World Status: 0
#   Time Step: 15, Government Utility: 0.5021680495438335, Protestors Ratio: 0.10752688172043011, World Status: 0
#   Time Step: 16, Government Utility: 0.4730754431788242, Protestors Ratio: 0.0931899641577061, World Status: 0
#   Time Step: 17, Government Utility: 0.4487041336665196, Protestors Ratio: 0.07526881720430108, World Status: 0
#   Time Step: 18, Government Utility: 0.4298882771696122, Protestors Ratio: 0.043010752688172046, World Status: 0
#   Time Step: 19, Government Utility: 0.41567552322029444, Protestors Ratio: 0.025089605734767026, World Status: 0
#   Time Step: 20, Government Utility: 0.40823224688862164, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 21, Government Utility: 0.4017572017050314, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 22, Government Utility: 0.3955760463688561, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 23, Government Utility: 0.3881546568785046, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 24, Government Utility: 0.381682767770419, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 25, Government Utility: 0.37511929876951167, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 26, Government Utility: 0.368577503996321, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 27, Government Utility: 0.3623856493954256, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 28, Government Utility: 0.3575484742966434, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 29, Government Utility: 0.3502441616137843, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 30, Government Utility: 0.3437801146889307, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 31, Government Utility: 0.3367232026247859, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 32, Government Utility: 0.3303554794477055, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 33, Government Utility: 0.322237555708316, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 34, Government Utility: 0.3163185392072793, Protestors Ratio: 0.017921146953405017, World Status: 0
#   Time Step: 35, Government Utility: 0.31087804390457074, Protestors Ratio: 0.017921146953405017, World Status: 0
#   Time Step: 36, Government Utility: 0.30580858997052895, Protestors Ratio: 0.017921146953405017, World Status: 0
#   Time Step: 37, Government Utility: 0.30036455932678136, Protestors Ratio: 0.017921146953405017, World Status: 0
#   Time Step: 38, Government Utility: 0.29500259211489066, Protestors Ratio: 0.017921146953405017, World Status: 0
#   Time Step: 39, Government Utility: 0.2902033209080594, Protestors Ratio: 0.017921146953405017, World Status: 0
#   Time Step: 40, Government Utility: 0.28429965657446615, Protestors Ratio: 0.017921146953405017, World Status: 0
#   Time Step: 41, Government Utility: 0.27804787710356693, Protestors Ratio: 0.014336917562724014, World Status: 0
#   Time Step: 42, Government Utility: 0.2738666374141611, Protestors Ratio: 0.014336917562724014, World Status: 0
#   Time Step: 43, Government Utility: 0.2696425147319883, Protestors Ratio: 0.014336917562724014, World Status: 0
#   Time Step: 44, Government Utility: 0.2651548225775722, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 45, Government Utility: 0.26133426748600314, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 46, Government Utility: 0.25850588179512785, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 47, Government Utility: 0.25519168704214945, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 48, Government Utility: 0.25216007728094597, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 49, Government Utility: 0.24908582859905762, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 50, Government Utility: 0.2454788424396564, Protestors Ratio: 0.010752688172043012, World Status: 0
# Iteration 3/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9953125, Protestors Ratio: 0.046875, World Status: 0
#   Time Step: 3, Government Utility: 0.9149076025698781, Protestors Ratio: 0.05625, World Status: 0
#   Time Step: 4, Government Utility: 0.9020352823988533, Protestors Ratio: 0.08125, World Status: 0
#   Time Step: 5, Government Utility: 0.7885836275543266, Protestors Ratio: 0.08125, World Status: 0
#   Time Step: 6, Government Utility: 0.7841421135796506, Protestors Ratio: 0.165625, World Status: 0
#   Time Step: 7, Government Utility: 0.7377280856126082, Protestors Ratio: 0.23125, World Status: 0
#   Time Step: 8, Government Utility: 0, Protestors Ratio: 0.43729903536977494, World Status: 1
# Iteration 4/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9965625, Protestors Ratio: 0.034375, World Status: 0
#   Time Step: 3, Government Utility: 0.9846248001686478, Protestors Ratio: 0.0375, World Status: 0
#   Time Step: 4, Government Utility: 0.9653076745978235, Protestors Ratio: 0.065625, World Status: 0
#   Time Step: 5, Government Utility: 0.9346453899681587, Protestors Ratio: 0.1125, World Status: 0
#   Time Step: 6, Government Utility: 0.6695526191939374, Protestors Ratio: 0.153125, World Status: 0
#   Time Step: 7, Government Utility: 0, Protestors Ratio: 0.3875, World Status: 1
# Iteration 5/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9978125, Protestors Ratio: 0.021875, World Status: 0
#   Time Step: 3, Government Utility: 0.9854665193589861, Protestors Ratio: 0.021875, World Status: 0
#   Time Step: 4, Government Utility: 1, Protestors Ratio: 0.034375, World Status: 0
#   Time Step: 5, Government Utility: 0.9568443416270396, Protestors Ratio: 0.025, World Status: 0
#   Time Step: 6, Government Utility: 1, Protestors Ratio: 0.075, World Status: 0
#   Time Step: 7, Government Utility: 0.8138065418890508, Protestors Ratio: 0.075, World Status: 0
#   Time Step: 8, Government Utility: 0.8102694080223489, Protestors Ratio: 0.221875, World Status: 0
#   Time Step: 9, Government Utility: 0.6599938525339559, Protestors Ratio: 0.25, World Status: 0
#   Time Step: 10, Government Utility: 0, Protestors Ratio: 0.46254071661237783, World Status: 1
# Iteration 6/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9978125, Protestors Ratio: 0.021875, World Status: 0
#   Time Step: 3, Government Utility: 0.955416595785353, Protestors Ratio: 0.028125, World Status: 0
#   Time Step: 4, Government Utility: 0.9327721355264195, Protestors Ratio: 0.059375, World Status: 0
#   Time Step: 5, Government Utility: 0.8813405011751423, Protestors Ratio: 0.09375, World Status: 0
#   Time Step: 6, Government Utility: 0.7195494038072213, Protestors Ratio: 0.153125, World Status: 0
#   Time Step: 7, Government Utility: 0, Protestors Ratio: 0.38125, World Status: 1
# Iteration 7/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9978125, Protestors Ratio: 0.021875, World Status: 0
#   Time Step: 3, Government Utility: 0.9852813344940108, Protestors Ratio: 0.03125, World Status: 0
#   Time Step: 4, Government Utility: 0.988987131648024, Protestors Ratio: 0.046875, World Status: 0
#   Time Step: 5, Government Utility: 0.9481032640394418, Protestors Ratio: 0.046875, World Status: 0
#   Time Step: 6, Government Utility: 1, Protestors Ratio: 0.065625, World Status: 0
#   Time Step: 7, Government Utility: 0.8844060741909949, Protestors Ratio: 0.0625, World Status: 0
#   Time Step: 8, Government Utility: 0.8682392854406085, Protestors Ratio: 0.13125, World Status: 0
#   Time Step: 9, Government Utility: 0.7281181015885542, Protestors Ratio: 0.178125, World Status: 0
#   Time Step: 10, Government Utility: 0, Protestors Ratio: 0.496875, World Status: 1
# Iteration 8/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.99875, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 3, Government Utility: 0.9951387736466499, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 4, Government Utility: 0.9916783694833201, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 5, Government Utility: 0.98778704330083, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 6, Government Utility: 0.9833396318398191, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 7, Government Utility: 0.9794969280957366, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 8, Government Utility: 0.9753644658778701, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 9, Government Utility: 0.9708116429221529, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 10, Government Utility: 0.96647492251454, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 11, Government Utility: 0.957360926797703, Protestors Ratio: 0.021875, World Status: 0
#   Time Step: 12, Government Utility: 0.9398270733527311, Protestors Ratio: 0.034375, World Status: 0
#   Time Step: 13, Government Utility: 0.9114735694441348, Protestors Ratio: 0.040625, World Status: 0
#   Time Step: 14, Government Utility: 0.8925459541462777, Protestors Ratio: 0.040625, World Status: 0
#   Time Step: 15, Government Utility: 0.8724977761146351, Protestors Ratio: 0.0625, World Status: 0
#   Time Step: 16, Government Utility: 0.7809766762089481, Protestors Ratio: 0.078125, World Status: 0
#   Time Step: 17, Government Utility: 0.7287165293842912, Protestors Ratio: 0.096875, World Status: 0
#   Time Step: 18, Government Utility: 0.5985026120848864, Protestors Ratio: 0.1375, World Status: 0
#   Time Step: 19, Government Utility: 0.4993402026242436, Protestors Ratio: 0.34375, World Status: 0
#   Time Step: 20, Government Utility: 0.32146687015887243, Protestors Ratio: 0.21875, World Status: 0
#   Time Step: 21, Government Utility: 0.271642355651602, Protestors Ratio: 0.22377622377622378, World Status: 0
#   Time Step: 22, Government Utility: 0.21424595887124925, Protestors Ratio: 0.18705035971223022, World Status: 0
#   Time Step: 23, Government Utility: 0.1777754064379795, Protestors Ratio: 0.16304347826086957, World Status: 0
#   Time Step: 24, Government Utility: 0.1227171420900858, Protestors Ratio: 0.14492753623188406, World Status: 0
#   Time Step: 25, Government Utility: 0.0843850855209641, Protestors Ratio: 0.10909090909090909, World Status: 0
#   Time Step: 26, Government Utility: 0.05481643731055043, Protestors Ratio: 0.08727272727272728, World Status: 0
#   Time Step: 27, Government Utility: 0.033149111987191116, Protestors Ratio: 0.06545454545454546, World Status: 0
#   Time Step: 28, Government Utility: 0.011939022802631795, Protestors Ratio: 0.04727272727272727, World Status: 0
#   Time Step: 29, Government Utility: 0.0024190521878489704, Protestors Ratio: 0.01818181818181818, World Status: 0
#   Time Step: 30, Government Utility: -0.00831478123804543, Protestors Ratio: 0.0, World Status: 0
# Iteration 9/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9975, Protestors Ratio: 0.025, World Status: 0
#   Time Step: 3, Government Utility: 0.9792877427039308, Protestors Ratio: 0.03125, World Status: 0
#   Time Step: 4, Government Utility: 0.9784275435242127, Protestors Ratio: 0.053125, World Status: 0
#   Time Step: 5, Government Utility: 0.9143675532334049, Protestors Ratio: 0.053125, World Status: 0
#   Time Step: 6, Government Utility: 0.8956679937011447, Protestors Ratio: 0.084375, World Status: 0
#   Time Step: 7, Government Utility: 0.7352569478541546, Protestors Ratio: 0.0875, World Status: 0
#   Time Step: 8, Government Utility: 0.6829244690690348, Protestors Ratio: 0.18125, World Status: 0
#   Time Step: 9, Government Utility: 0.596696047450425, Protestors Ratio: 0.303125, World Status: 0
#   Time Step: 10, Government Utility: 0.4140177265856235, Protestors Ratio: 0.23728813559322035, World Status: 0
#   Time Step: 11, Government Utility: 0.36419091984660196, Protestors Ratio: 0.21107266435986158, World Status: 0
#   Time Step: 12, Government Utility: 0.32859889790432417, Protestors Ratio: 0.17375886524822695, World Status: 0
#   Time Step: 13, Government Utility: 0.30083752637220884, Protestors Ratio: 0.12903225806451613, World Status: 0
#   Time Step: 14, Government Utility: 0.2646458248724032, Protestors Ratio: 0.1111111111111111, World Status: 0
#   Time Step: 15, Government Utility: 0.23651475706927733, Protestors Ratio: 0.08960573476702509, World Status: 0
#   Time Step: 16, Government Utility: 0.200664781677924, Protestors Ratio: 0.06810035842293907, World Status: 0
#   Time Step: 17, Government Utility: 0.1803341996680807, Protestors Ratio: 0.04659498207885305, World Status: 0
#   Time Step: 18, Government Utility: 0.16526114066797004, Protestors Ratio: 0.021505376344086023, World Status: 0
#   Time Step: 19, Government Utility: 0.1608770934598013, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 20, Government Utility: 0.1562805524663404, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 21, Government Utility: 0.15233165314257985, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 22, Government Utility: 0.1484249814915078, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 23, Government Utility: 0.14524314341260874, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 24, Government Utility: 0.1425246886879841, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 25, Government Utility: 0.13908996445053826, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 26, Government Utility: 0.1356320528318895, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 27, Government Utility: 0.13215942200461867, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 28, Government Utility: 0.1292186796962406, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 29, Government Utility: 0.12663060272550833, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 30, Government Utility: 0.12251345251658009, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 31, Government Utility: 0.11942431550266087, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 32, Government Utility: 0.11555132118879351, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 33, Government Utility: 0.11220578621439853, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 34, Government Utility: 0.10965251363478573, Protestors Ratio: 0.007168458781362007, World Status: 0
#   Time Step: 35, Government Utility: 0.10790609427390967, Protestors Ratio: 0.007168458781362007, World Status: 0
#   Time Step: 36, Government Utility: 0.10570359973102471, Protestors Ratio: 0.007168458781362007, World Status: 0
#   Time Step: 37, Government Utility: 0.10396248420126505, Protestors Ratio: 0.007168458781362007, World Status: 0
#   Time Step: 38, Government Utility: 0.10181061784137414, Protestors Ratio: 0.007168458781362007, World Status: 0
#   Time Step: 39, Government Utility: 0.09927203777818096, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 40, Government Utility: 0.09629621636456, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 41, Government Utility: 0.09320825149013902, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 42, Government Utility: 0.08896756871510507, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 43, Government Utility: 0.08600319699669526, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 44, Government Utility: 0.08357401845548677, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 45, Government Utility: 0.08003896479540883, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 46, Government Utility: 0.07684181977102618, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 47, Government Utility: 0.0746765179542982, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 48, Government Utility: 0.07124822349374552, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 49, Government Utility: 0.06808312138422513, Protestors Ratio: 0.010752688172043012, World Status: 0
#   Time Step: 50, Government Utility: 0.0648657214882295, Protestors Ratio: 0.010752688172043012, World Status: 0
# Iteration 10/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.996875, Protestors Ratio: 0.03125, World Status: 0
#   Time Step: 3, Government Utility: 0.9864873130463032, Protestors Ratio: 0.040625, World Status: 0
#   Time Step: 4, Government Utility: 0.9632134796847293, Protestors Ratio: 0.05625, World Status: 0
#   Time Step: 5, Government Utility: 0.908432414839482, Protestors Ratio: 0.078125, World Status: 0
#   Time Step: 6, Government Utility: 0.7757396183328542, Protestors Ratio: 0.096875, World Status: 0
#   Time Step: 7, Government Utility: 0.7175827484432773, Protestors Ratio: 0.13125, World Status: 0
#   Time Step: 8, Government Utility: 0.6559069783921212, Protestors Ratio: 0.196875, World Status: 0
#   Time Step: 9, Government Utility: 0.46523798686433443, Protestors Ratio: 0.34591194968553457, World Status: 0
#   Time Step: 10, Government Utility: 0.3333474507539904, Protestors Ratio: 0.23487544483985764, World Status: 0
#   Time Step: 11, Government Utility: 0.2874022455567796, Protestors Ratio: 0.19494584837545126, World Status: 0
#   Time Step: 12, Government Utility: 0.23966800315078185, Protestors Ratio: 0.16058394160583941, World Status: 0
#   Time Step: 13, Government Utility: 0.20595368343477333, Protestors Ratio: 0.13503649635036497, World Status: 0
#   Time Step: 14, Government Utility: 0.1615176590883014, Protestors Ratio: 0.11678832116788321, World Status: 0
#   Time Step: 15, Government Utility: 0.12903965610379256, Protestors Ratio: 0.09124087591240876, World Status: 0
#   Time Step: 16, Government Utility: 0.10031149844589123, Protestors Ratio: 0.08029197080291971, World Status: 0
#   Time Step: 17, Government Utility: 0.0751196601969885, Protestors Ratio: 0.06934306569343066, World Status: 0
#   Time Step: 18, Government Utility: 0.05117275575562933, Protestors Ratio: 0.05474452554744526, World Status: 0
#   Time Step: 19, Government Utility: 0.037443677455222216, Protestors Ratio: 0.029197080291970802, World Status: 0
#   Time Step: 20, Government Utility: 0.030956874043495314, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 21, Government Utility: 0.029835422431806084, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 22, Government Utility: 0.028620672299523024, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 23, Government Utility: 0.02765947651857859, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 24, Government Utility: 0.025857183493533477, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 25, Government Utility: 0.024764065356724225, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 26, Government Utility: 0.023793496652842073, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 27, Government Utility: 0.022936080918185397, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 28, Government Utility: 0.0214496923063312, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 29, Government Utility: 0.020337302262643166, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 30, Government Utility: 0.019309299594468927, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 31, Government Utility: 0.017864210509809336, Protestors Ratio: 0.0072992700729927005, World Status: 0
#   Time Step: 32, Government Utility: 0.016056132353575114, Protestors Ratio: 0.0036496350364963502, World Status: 0
#   Time Step: 33, Government Utility: 0.014605816613504609, Protestors Ratio: 0.0072992700729927005, World Status: 0
#   Time Step: 34, Government Utility: 0.012405825182498501, Protestors Ratio: 0.0072992700729927005, World Status: 0
#   Time Step: 35, Government Utility: 0.011413381935821061, Protestors Ratio: 0.0072992700729927005, World Status: 0
#   Time Step: 36, Government Utility: 0.009124878544562362, Protestors Ratio: 0.0072992700729927005, World Status: 0
#   Time Step: 37, Government Utility: 0.007283029876082099, Protestors Ratio: 0.0072992700729927005, World Status: 0
#   Time Step: 38, Government Utility: 0.004361396460133425, Protestors Ratio: 0.0072992700729927005, World Status: 0
#   Time Step: 39, Government Utility: 0.002512268374678591, Protestors Ratio: 0.0072992700729927005, World Status: 0
#   Time Step: 40, Government Utility: 0.00026278864109609886, Protestors Ratio: 0.0072992700729927005, World Status: 0
#   Time Step: 41, Government Utility: -0.0009603131577969669, Protestors Ratio: 0.0072992700729927005, World Status: 0
# Iteration 11/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9975, Protestors Ratio: 0.025, World Status: 0
#   Time Step: 3, Government Utility: 0.9640476585693418, Protestors Ratio: 0.028125, World Status: 0
#   Time Step: 4, Government Utility: 0.9500012814793629, Protestors Ratio: 0.028125, World Status: 0
#   Time Step: 5, Government Utility: 0.9372431213012734, Protestors Ratio: 0.028125, World Status: 0
#   Time Step: 6, Government Utility: 0.9259066298682049, Protestors Ratio: 0.034375, World Status: 0
#   Time Step: 7, Government Utility: 0.932738853309874, Protestors Ratio: 0.0375, World Status: 0
#   Time Step: 8, Government Utility: 0.9178338458986709, Protestors Ratio: 0.0375, World Status: 0
#   Time Step: 9, Government Utility: 0.8871919667274168, Protestors Ratio: 0.040625, World Status: 0
#   Time Step: 10, Government Utility: 0.8869688404376536, Protestors Ratio: 0.0625, World Status: 0
#   Time Step: 11, Government Utility: 0.8169572613352387, Protestors Ratio: 0.0625, World Status: 0
#   Time Step: 12, Government Utility: 0.8084503160580924, Protestors Ratio: 0.1625, World Status: 0
#   Time Step: 13, Government Utility: 0.5033545618935895, Protestors Ratio: 0.203125, World Status: 0
#   Time Step: 14, Government Utility: 0, Protestors Ratio: 0.5440251572327044, World Status: 1
# Iteration 12/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9978125, Protestors Ratio: 0.021875, World Status: 0
#   Time Step: 3, Government Utility: 0.9584653342667843, Protestors Ratio: 0.040625, World Status: 0
#   Time Step: 4, Government Utility: 0.9886082268180447, Protestors Ratio: 0.05, World Status: 0
#   Time Step: 5, Government Utility: 0.9196477584220326, Protestors Ratio: 0.046875, World Status: 0
#   Time Step: 6, Government Utility: 0.9828757312693295, Protestors Ratio: 0.09375, World Status: 0
#   Time Step: 7, Government Utility: 0.9215653775370662, Protestors Ratio: 0.090625, World Status: 0
#   Time Step: 8, Government Utility: 0.9198851679163346, Protestors Ratio: 0.259375, World Status: 0
#   Time Step: 9, Government Utility: 0, Protestors Ratio: 0.434375, World Status: 1
# ...
#   Time Step: 5, Government Utility: 0.8447030452461058, Protestors Ratio: 0.053125, World Status: 0
#   Time Step: 6, Government Utility: 0.8405096735439349, Protestors Ratio: 0.08125, World Status: 0
#   Time Step: 7, Government Utility: 0.7052313206790297, Protestors Ratio: 0.090625, World Status: 0
#   Time Step: 8, Government Utility: 0.6527093798032824, Protestors Ratio: 0.234375, World Status: 0
#   Time Step: 9, Government Utility: 0, Protestors Ratio: 0.4528301886792453, World Status: 1
# Iteration 197/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.9971875, Protestors Ratio: 0.028125, World Status: 0
#   Time Step: 3, Government Utility: 0.9802440372369422, Protestors Ratio: 0.028125, World Status: 0
#   Time Step: 4, Government Utility: 0.9722756845867833, Protestors Ratio: 0.046875, World Status: 0
#   Time Step: 5, Government Utility: 0.9463011887868369, Protestors Ratio: 0.05, World Status: 0
#   Time Step: 6, Government Utility: 0.915145279087135, Protestors Ratio: 0.05625, World Status: 0
#   Time Step: 7, Government Utility: 0.8260744418529452, Protestors Ratio: 0.103125, World Status: 0
#   Time Step: 8, Government Utility: 0.7812046552626687, Protestors Ratio: 0.196875, World Status: 0
#   Time Step: 9, Government Utility: 0, Protestors Ratio: 0.421875, World Status: 1
# Iteration 198/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.999375, Protestors Ratio: 0.00625, World Status: 0
#   Time Step: 3, Government Utility: 0.9979966507052432, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 4, Government Utility: 0.9956103801199458, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 5, Government Utility: 0.992816459994521, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 6, Government Utility: 0.9903935383560938, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 7, Government Utility: 0.9880375528907444, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 8, Government Utility: 0.9855176978496605, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 9, Government Utility: 0.9828346073435807, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 10, Government Utility: 0.9800815269704427, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 11, Government Utility: 0.97704307150454, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 12, Government Utility: 0.973799485154342, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 13, Government Utility: 0.9718375070953358, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 14, Government Utility: 0.9685939489242154, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 15, Government Utility: 0.9653342548960349, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 16, Government Utility: 0.9631111447170596, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 17, Government Utility: 0.9599766768547959, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 18, Government Utility: 0.9567217394497852, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 19, Government Utility: 0.9547043030970518, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 20, Government Utility: 0.9516919043072768, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 21, Government Utility: 0.9497355540018549, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 22, Government Utility: 0.947801947840124, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 23, Government Utility: 0.9441592340022161, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 24, Government Utility: 0.94061932165225, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 25, Government Utility: 0.9371880983458534, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 26, Government Utility: 0.934225030976938, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 27, Government Utility: 0.9329546770177929, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 28, Government Utility: 0.9310337305901197, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 29, Government Utility: 0.9286991621749854, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 30, Government Utility: 0.9267288674863251, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 31, Government Utility: 0.9240630810086295, Protestors Ratio: 0.009375, World Status: 0
#   Time Step: 32, Government Utility: 0.9206355506420137, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 33, Government Utility: 0.9165917939397022, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 34, Government Utility: 0.9142827330761443, Protestors Ratio: 0.015625, World Status: 0
#   Time Step: 35, Government Utility: 0.9099106253223059, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 36, Government Utility: 0.9077466477927688, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 37, Government Utility: 0.9043460275251695, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 38, Government Utility: 0.9006401903936117, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 39, Government Utility: 0.8971726536038895, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 40, Government Utility: 0.8935262216955124, Protestors Ratio: 0.0125, World Status: 0
#   Time Step: 41, Government Utility: 0.8904286698919253, Protestors Ratio: 0.00625, World Status: 0
#   Time Step: 42, Government Utility: 0.8900237979674824, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 43, Government Utility: 0.8900237979674824, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 44, Government Utility: 0.8900237979674824, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 45, Government Utility: 0.8900237979674824, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 46, Government Utility: 0.8897112979674824, Protestors Ratio: 0.003125, World Status: 0
#   Time Step: 47, Government Utility: 0.8888254003489277, Protestors Ratio: 0.003125, World Status: 0
#   Time Step: 48, Government Utility: 0.8877543003340439, Protestors Ratio: 0.00625, World Status: 0
#   Time Step: 49, Government Utility: 0.8864540112488243, Protestors Ratio: 0.00625, World Status: 0
#   Time Step: 50, Government Utility: 0.8852380246520278, Protestors Ratio: 0.00625, World Status: 0
# Iteration 199/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.995625, Protestors Ratio: 0.04375, World Status: 0
#   Time Step: 3, Government Utility: 0.9783491547450439, Protestors Ratio: 0.05625, World Status: 0
#   Time Step: 4, Government Utility: 0.9695351656034177, Protestors Ratio: 0.09375, World Status: 0
#   Time Step: 5, Government Utility: 0.8302147640297304, Protestors Ratio: 0.096875, World Status: 0
#   Time Step: 6, Government Utility: 0.7858945537209437, Protestors Ratio: 0.2125, World Status: 0
#   Time Step: 7, Government Utility: 0, Protestors Ratio: 0.4, World Status: 1
# Iteration 200/200, Strategy: Suppression and Indirect Reform Strategy, Legitimacy: 0.8, Vision: High, Shock Rate: Low, Cops Ratio: High
#   Time Step: 1, Government Utility: 1.0, Protestors Ratio: 0.0, World Status: 0
#   Time Step: 2, Government Utility: 0.998125, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 3, Government Utility: 0.9924207883613125, Protestors Ratio: 0.01875, World Status: 0
#   Time Step: 4, Government Utility: 0.990769488956859, Protestors Ratio: 0.040625, World Status: 0
#   Time Step: 5, Government Utility: 0.9630778843714886, Protestors Ratio: 0.040625, World Status: 0
#   Time Step: 6, Government Utility: 0.9444573530051843, Protestors Ratio: 0.05, World Status: 0
#   Time Step: 7, Government Utility: 0.9053477876329603, Protestors Ratio: 0.053125, World Status: 0
#   Time Step: 8, Government Utility: 0.7991997267518998, Protestors Ratio: 0.071875, World Status: 0
#   Time Step: 9, Government Utility: 0.770316166134484, Protestors Ratio: 0.140625, World Status: 0
#   Time Step: 10, Government Utility: 0.5253986675944194, Protestors Ratio: 0.240625, World Status: 0
#   Time Step: 11, Government Utility: 0.3805641065171985, Protestors Ratio: 0.2783171521035599, World Status: 0
#   Time Step: 12, Government Utility: 0.308201682550373, Protestors Ratio: 0.24149659863945577, World Status: 0
#   Time Step: 13, Government Utility: 0.24454324794624735, Protestors Ratio: 0.2268041237113402, World Status: 0
#   Time Step: 14, Government Utility: 0.19806702812356317, Protestors Ratio: 0.1696113074204947, World Status: 0
#   Time Step: 15, Government Utility: 0.16335557714187313, Protestors Ratio: 0.14590747330960854, World Status: 0
#   Time Step: 16, Government Utility: 0.12118315315575713, Protestors Ratio: 0.11387900355871886, World Status: 0
#   Time Step: 17, Government Utility: 0.08984146674111615, Protestors Ratio: 0.09252669039145907, World Status: 0
#   Time Step: 18, Government Utility: 0.06609069323848897, Protestors Ratio: 0.046263345195729534, World Status: 0
#   Time Step: 19, Government Utility: 0.0450477901825625, Protestors Ratio: 0.03558718861209965, World Status: 0
#   Time Step: 20, Government Utility: 0.03455905744026746, Protestors Ratio: 0.017793594306049824, World Status: 0
#   Time Step: 21, Government Utility: 0.027815675151989815, Protestors Ratio: 0.017793594306049824, World Status: 0
#   Time Step: 22, Government Utility: 0.022206671670418093, Protestors Ratio: 0.017793594306049824, World Status: 0
#   Time Step: 23, Government Utility: 0.016810865469646365, Protestors Ratio: 0.017793594306049824, World Status: 0
#   Time Step: 24, Government Utility: 0.0115509728123502, Protestors Ratio: 0.017793594306049824, World Status: 0
#   Time Step: 25, Government Utility: 0.00616527625920029, Protestors Ratio: 0.017793594306049824, World Status: 0
#   Time Step: 26, Government Utility: 0.0008659474204911121, Protestors Ratio: 0.017793594306049824, World Status: 0
#   Time Step: 27, Government Utility: -0.005606601364398635, Protestors Ratio: 0.021352313167259787, World Status: 0
#
# Summary of Average Government Lifetime Utility and Stability by Strategy and Legitimacy Level
#
#                 Avg Duration of Stability                         \
# Strategy                Consistent Reform Consistent Suppression
# Base Legitimacy
# 0.2                                2.0000                 2.0000
# 0.4                                3.2125                32.9650
# 0.6                               36.4700                16.0275
# 0.8                               39.6550                20.2700
#
#                                                           \
# Strategy        Suppression and Indirect Reform Strategy
# Base Legitimacy
# 0.2                                               2.0000
# 0.4                                              28.6000
# 0.6                                              14.4575
# 0.8                                              16.8925
#
#                 Avg Gov Lifetime Utility                         \
# Strategy               Consistent Reform Consistent Suppression
# Base Legitimacy
# 0.2                             1.000000               1.000000
# 0.4                             1.964821               8.563318
# 0.6                            10.712548               4.853793
# 0.8                            14.463552               7.464277
#
#
# Strategy        Suppression and Indirect Reform Strategy
# Base Legitimacy
# 0.2                                             1.000000
# 0.4                                             7.562012
# 0.6                                             4.245468
# 0.8                                             7.194893
#
# Comparison of Strategies Across Different Shock Rates
#
#            Avg Duration of Stability                         \
# Strategy           Consistent Reform Consistent Suppression
# Shock Rate
# High                        14.30500               16.84500
# Low                         26.36375               18.78625
#
#                                                     Avg Gov Lifetime Utility  \
# Strategy   Suppression and Indirect Reform Strategy        Consistent Reform
# Shock Rate
# High                                       11.99875                 5.899029
# Low                                        18.97625                 8.171431
#
#
# Strategy   Consistent Suppression Suppression and Indirect Reform Strategy
# Shock Rate
# High                     5.075311                                 4.373452
# Low                      5.865383                                 5.627735
#
# Detailed Results for Each Scenario
#
#                              Avg Duration of Stability                         \
# Strategy                             Consistent Reform Consistent Suppression
# Vision Shock Rate Cops Ratio
# High   High       High                        14.30500               16.84500
#        Low        High                        26.36375               18.78625
#
#                                                                        \
# Strategy                     Suppression and Indirect Reform Strategy
# Vision Shock Rate Cops Ratio
# High   High       High                                       11.99875
#        Low        High                                       18.97625
#
#                              Avg Gov Lifetime Utility                         \
# Strategy                            Consistent Reform Consistent Suppression
# Vision Shock Rate Cops Ratio
# High   High       High                       5.899029               5.075311
#        Low        High                       8.171431               5.865383
#
#
# Strategy                     Suppression and Indirect Reform Strategy
# Vision Shock Rate Cops Ratio
# High   High       High                                       4.373452
#        Low        High                                       5.627735
# Plotting scenario: Low Legitimacy with 12 data points.
# Plotting scenario: High Shock Rate with 12 data points.
# Plotting scenario: High Vision with 24 data points.
# Plotting scenario: High Cops Ratio with 24 data points.
# Plotting scenario: High Vision, High Shock Rate, High Cops Ratio with 12 data points.
# Plotting scenario: Low Shock Rate with 12 data points.
# Plotting scenario: High Vision, Low Shock Rate, High Cops Ratio with 12 data points.
# Plotting scenario: High Legitimacy with 12 data points.
# Plotting scenario: Low Legitimacy with 12 data points.
# Plotting scenario: High Shock Rate with 12 data points.
# Plotting scenario: High Vision with 24 data points.
# Plotting scenario: High Cops Ratio with 24 data points.
# Plotting scenario: High Vision, High Shock Rate, High Cops Ratio with 12 data points.
# Plotting scenario: Low Shock Rate with 12 data points.
# Plotting scenario: High Vision, Low Shock Rate, High Cops Ratio with 12 data points.
# Plotting scenario: High Legitimacy with 12 data points.
